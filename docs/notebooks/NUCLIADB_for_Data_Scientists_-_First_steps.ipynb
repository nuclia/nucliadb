# %%
! pip install nucliadb-sdk==1.2.5
! pip install nucliadb-dataset==1.2.3
! pip install nucliadb-models==2.0.4
! pip install sentence-transformers
import requests
from nucliadb_sdk.knowledgebox import KnowledgeBox
from nucliadb_sdk.labels import Label
from nucliadb_sdk.utils import create_knowledge_box, get_or_create
from sentence_transformers import SentenceTransformer
# Out:
# Looking in indexes: https://pypi.org/simple, https://_json_key_base64:****@europe-west4-python.pkg.dev/stashify-218417/stashify-python/simple/
# Collecting nucliadb-sdk==1.2.5
#   Downloading nucliadb_sdk-1.2.5-py3-none-any.whl (24 kB)
# Requirement already satisfied: httpx in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-sdk==1.2.5) (0.23.0)
# Requirement already satisfied: nucliadb-models>=2.0.2 in /Users/ramon/nuclia/nucliadb/nucliadb_models (from nucliadb-sdk==1.2.5) (2.0.4)
# Requirement already satisfied: pydantic>=1.8.2 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (1.10.2)
# Requirement already satisfied: nucliadb_protos>=0.0.36 in /Users/ramon/nuclia/nucliadb/nucliadb_protos/python (from nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (0.0.45)
# Requirement already satisfied: certifi in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpx->nucliadb-sdk==1.2.5) (2022.9.24)
# Requirement already satisfied: sniffio in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpx->nucliadb-sdk==1.2.5) (1.3.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpx->nucliadb-sdk==1.2.5) (1.5.0)
# Requirement already satisfied: httpcore<0.16.0,>=0.15.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpx->nucliadb-sdk==1.2.5) (0.15.0)
# Requirement already satisfied: anyio==3.* in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpcore<0.16.0,>=0.15.0->httpx->nucliadb-sdk==1.2.5) (3.6.2)
# Requirement already satisfied: h11<0.13,>=0.11 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpcore<0.16.0,>=0.15.0->httpx->nucliadb-sdk==1.2.5) (0.12.0)
# Requirement already satisfied: idna>=2.8 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from anyio==3.*->httpcore<0.16.0,>=0.15.0->httpx->nucliadb-sdk==1.2.5) (3.4)
# Requirement already satisfied: protobuf in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (3.20.3)
# Requirement already satisfied: grpcio>=1.44.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (1.51.1)
# Requirement already satisfied: grpcio-tools>=1.44.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (1.51.1)
# Requirement already satisfied: mypy-protobuf>=3.2.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from pydantic>=1.8.2->nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (4.4.0)
# Collecting protobuf
#   Using cached protobuf-4.21.12-cp37-abi3-macosx_10_9_universal2.whl (486 kB)
# Requirement already satisfied: setuptools in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from grpcio-tools>=1.44.0->nucliadb_protos>=0.0.36->nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (65.6.3)
# Requirement already satisfied: types-protobuf>=3.19.12 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from mypy-protobuf>=3.2.0->nucliadb_protos>=0.0.36->nucliadb-models>=2.0.2->nucliadb-sdk==1.2.5) (3.20.4.6)
# Installing collected packages: protobuf, nucliadb-sdk
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: nucliadb-sdk
#     Found existing installation: nucliadb-sdk 1.2.3
#     Uninstalling nucliadb-sdk-1.2.3:
#       Successfully uninstalled nucliadb-sdk-1.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.11.0 requires protobuf<4,>=3.9.2, but you have protobuf 4.21.12 which is incompatible.
# Successfully installed nucliadb-sdk-1.2.5 protobuf-4.21.12
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://_json_key_base64:****@europe-west4-python.pkg.dev/stashify-218417/stashify-python/simple/
# Collecting nucliadb-dataset==1.2.3
#   Downloading nucliadb_dataset-1.2.3-py3-none-any.whl (15 kB)
# Requirement already satisfied: boto3-stubs in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (1.26.52)
# Requirement already satisfied: requests in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (2.28.1)
# Requirement already satisfied: pyarrow in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (10.0.1)
# Requirement already satisfied: nucliadb-protos in /Users/ramon/nuclia/nucliadb/nucliadb_protos/python (from nucliadb-dataset==1.2.3) (0.0.45)
# Requirement already satisfied: google-auth in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (2.15.0)
# Requirement already satisfied: types-boto3 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (1.0.2)
# Requirement already satisfied: google-cloud-storage in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (2.6.0)
# Collecting types-google-cloud-ndb
#   Using cached types_google_cloud_ndb-2.1.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: nucliadb-sdk>=1.2.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (1.2.5)
# Requirement already satisfied: types-protobuf in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (3.20.4.6)
# Collecting google-auth-stubs
#   Using cached google_auth_stubs-0.2.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: boto3 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (1.24.59)
# Requirement already satisfied: protobuf in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (4.21.12)
# Requirement already satisfied: aiohttp in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (3.8.3)
# Requirement already satisfied: grpcio in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (1.51.1)
# Requirement already satisfied: pydantic-argparse in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-dataset==1.2.3) (0.6.1)
# Requirement already satisfied: httpx in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-sdk>=1.2.0->nucliadb-dataset==1.2.3) (0.23.0)
# Requirement already satisfied: nucliadb-models>=2.0.2 in /Users/ramon/nuclia/nucliadb/nucliadb_models (from nucliadb-sdk>=1.2.0->nucliadb-dataset==1.2.3) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from aiohttp->nucliadb-dataset==1.2.3) (6.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from aiohttp->nucliadb-dataset==1.2.3) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from aiohttp->nucliadb-dataset==1.2.3) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from aiohttp->nucliadb-dataset==1.2.3) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from aiohttp->nucliadb-dataset==1.2.3) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from aiohttp->nucliadb-dataset==1.2.3) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from aiohttp->nucliadb-dataset==1.2.3) (1.3.3)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from boto3->nucliadb-dataset==1.2.3) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.59 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from boto3->nucliadb-dataset==1.2.3) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from boto3->nucliadb-dataset==1.2.3) (1.0.1)
# Requirement already satisfied: botocore-stubs in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from boto3-stubs->nucliadb-dataset==1.2.3) (1.29.52)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from boto3-stubs->nucliadb-dataset==1.2.3) (4.4.0)
# Requirement already satisfied: types-s3transfer in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from boto3-stubs->nucliadb-dataset==1.2.3) (0.6.0.post5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-auth->nucliadb-dataset==1.2.3) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-auth->nucliadb-dataset==1.2.3) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-auth->nucliadb-dataset==1.2.3) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-auth->nucliadb-dataset==1.2.3) (4.9)
# Requirement already satisfied: grpc-stubs<2.0.0,>=1.24.7 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-auth-stubs->nucliadb-dataset==1.2.3) (1.24.7)
# Requirement already satisfied: types-requests<3.0.0,>=2.25.9 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-auth-stubs->nucliadb-dataset==1.2.3) (2.28.11.5)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-cloud-storage->nucliadb-dataset==1.2.3) (2.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-cloud-storage->nucliadb-dataset==1.2.3) (2.11.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-cloud-storage->nucliadb-dataset==1.2.3) (2.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from requests->nucliadb-dataset==1.2.3) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from requests->nucliadb-dataset==1.2.3) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from requests->nucliadb-dataset==1.2.3) (1.26.13)
# Requirement already satisfied: grpcio-tools>=1.44.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-protos->nucliadb-dataset==1.2.3) (1.51.1)
# Requirement already satisfied: mypy-protobuf>=3.2.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-protos->nucliadb-dataset==1.2.3) (3.3.0)
# Requirement already satisfied: numpy>=1.16.6 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from pyarrow->nucliadb-dataset==1.2.3) (1.23.5)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from pydantic-argparse->nucliadb-dataset==1.2.3) (1.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from botocore<1.28.0,>=1.27.59->boto3->nucliadb-dataset==1.2.3) (2.8.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->nucliadb-dataset==1.2.3) (1.57.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->nucliadb-dataset==1.2.3) (1.5.0)
# Requirement already satisfied: mypy>=0.902 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from grpc-stubs<2.0.0,>=1.24.7->google-auth-stubs->nucliadb-dataset==1.2.3) (0.991)
# Requirement already satisfied: setuptools in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from grpcio-tools>=1.44.0->nucliadb-protos->nucliadb-dataset==1.2.3) (65.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth->nucliadb-dataset==1.2.3) (0.4.8)
# Requirement already satisfied: types-urllib3<1.27 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from types-requests<3.0.0,>=2.25.9->google-auth-stubs->nucliadb-dataset==1.2.3) (1.26.25.4)
# Requirement already satisfied: types-awscrt in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from botocore-stubs->boto3-stubs->nucliadb-dataset==1.2.3) (0.16.4)
# Requirement already satisfied: httpcore<0.16.0,>=0.15.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpx->nucliadb-sdk>=1.2.0->nucliadb-dataset==1.2.3) (0.15.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpx->nucliadb-sdk>=1.2.0->nucliadb-dataset==1.2.3) (1.5.0)
# Requirement already satisfied: sniffio in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpx->nucliadb-sdk>=1.2.0->nucliadb-dataset==1.2.3) (1.3.0)
# Requirement already satisfied: anyio==3.* in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpcore<0.16.0,>=0.15.0->httpx->nucliadb-sdk>=1.2.0->nucliadb-dataset==1.2.3) (3.6.2)
# Requirement already satisfied: h11<0.13,>=0.11 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from httpcore<0.16.0,>=0.15.0->httpx->nucliadb-sdk>=1.2.0->nucliadb-dataset==1.2.3) (0.12.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from mypy>=0.902->grpc-stubs<2.0.0,>=1.24.7->google-auth-stubs->nucliadb-dataset==1.2.3) (0.4.3)
# Requirement already satisfied: tomli>=1.1.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from mypy>=0.902->grpc-stubs<2.0.0,>=1.24.7->google-auth-stubs->nucliadb-dataset==1.2.3) (2.0.1)
# Installing collected packages: types-google-cloud-ndb, google-auth-stubs, nucliadb-dataset
#   Attempting uninstall: nucliadb-dataset
#     Found existing installation: nucliadb-dataset 1.1.1
#     Uninstalling nucliadb-dataset-1.1.1:
#       Successfully uninstalled nucliadb-dataset-1.1.1
# Successfully installed google-auth-stubs-0.2.0 nucliadb-dataset-1.2.3 types-google-cloud-ndb-2.1.0.1
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://_json_key_base64:****@europe-west4-python.pkg.dev/stashify-218417/stashify-python/simple/
# Requirement already satisfied: nucliadb-models==2.0.4 in /Users/ramon/nuclia/nucliadb/nucliadb_models (2.0.4)
# Requirement already satisfied: pydantic>=1.8.2 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb-models==2.0.4) (1.10.2)
# Requirement already satisfied: nucliadb_protos>=0.0.36 in /Users/ramon/nuclia/nucliadb/nucliadb_protos/python (from nucliadb-models==2.0.4) (0.0.45)
# Requirement already satisfied: protobuf in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models==2.0.4) (4.21.12)
# Requirement already satisfied: grpcio>=1.44.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models==2.0.4) (1.51.1)
# Requirement already satisfied: grpcio-tools>=1.44.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models==2.0.4) (1.51.1)
# Requirement already satisfied: mypy-protobuf>=3.2.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nucliadb_protos>=0.0.36->nucliadb-models==2.0.4) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from pydantic>=1.8.2->nucliadb-models==2.0.4) (4.4.0)
# Requirement already satisfied: setuptools in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from grpcio-tools>=1.44.0->nucliadb_protos>=0.0.36->nucliadb-models==2.0.4) (65.6.3)
# Requirement already satisfied: types-protobuf>=3.19.12 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from mypy-protobuf>=3.2.0->nucliadb_protos>=0.0.36->nucliadb-models==2.0.4) (3.20.4.6)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://_json_key_base64:****@europe-west4-python.pkg.dev/stashify-218417/stashify-python/simple/
# Requirement already satisfied: sentence-transformers in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (4.25.1)
# Requirement already satisfied: nltk in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: sentencepiece in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: torchvision in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (0.14.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (0.12.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: tqdm in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: scipy in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (1.9.3)
# Requirement already satisfied: numpy in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from sentence-transformers) (1.1.3)
# Requirement already satisfied: packaging>=20.9 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.2)
# Requirement already satisfied: requests in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.4.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: joblib in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: click in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from torchvision->sentence-transformers) (9.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ramon/.pyenv/versions/3.10.8/envs/nucliadb/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Setup
#
# Make sure we've started **NucliaDB's container**
#
# ```
# docker run -it \
#        -e LOG=INFO \
#        -p 8080:8080 \
#        -p 8060:8060 \
#        -p 8040:8040 \
#        -v nucliadb-standalone:/data \
#        nuclia/nucliadb:latest
# ```
# Then, we'll check the connection:

# %%
response = requests.get(f"http://localhost:8080")
assert response.ok

# %% [markdown]
# ## Setup - creating a KB
#
# In nucliadb our data containers are called knowledge boxes.
#
# To start working, we need to create one:
#
# *We create it with the function get_or_create so that it won't be created again if it exists*

# %%
my_kb = get_or_create("my_reddit_data_kb2")

# %% [markdown]
# ## Setup - preparing data & model
#
# We download our dataset and the sentence embedding model we are going to use

# %%
from datasets import load_dataset
dataset = load_dataset("go_emotions", "raw")

sample = dataset["train"].shuffle(seed=19).select(range(10000))
# Out:
# Found cached dataset go_emotions (/Users/ramon/.cache/huggingface/datasets/go_emotions/raw/0.0.0/2637cfdd4e64d30249c3ed2150fa2b9d279766bfcd6a809b9f085c61a90d776d)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached shuffled indices for dataset at /Users/ramon/.cache/huggingface/datasets/go_emotions/raw/0.0.0/2637cfdd4e64d30249c3ed2150fa2b9d279766bfcd6a809b9f085c61a90d776d/cache-66031443094dc2fe.arrow

# %%
encoder = SentenceTransformer("all-MiniLM-L6-v2")

# %% [markdown]
# ## Uploading data to our KB
#
# we use the upload function to index text, labels and calculated vectors for each sentence of our dataset.
# Tips:
# - We can have more than one set of vectors in our data, just add another entry to the vectors dict `vectors={"roberta-vectors": vectors-roberta,"bert-vectors": vectors-bert }`
# - If you want to avoid uploading the same data twice by mistake, just add a `key` to your upload, its an unique identifier and it will update the resources when uploading them again instead of duplicating them. `key="my_reddit_sample"`
# - This can take a while! If you are in a hurry you can always select a smaller size when creating the sample

# %%
for row in sample:
    label = row["subreddit"]
    my_kb.upload(
        text=row["text"],
        labels=[f"reddit/{label}"],
        vectors={"all-MiniLM-L6-v2": encoder.encode([row["text"]])[0].tolist()},
    )
# Out:
# Vectorset is not created, we will create it for you

# %% [markdown]
# ## Checks
#
# We uploaded only data with one label.
# But we could have added more if we had code from other modules, or if we wanted to label some other code features
#
# Let's check if the numbers agree!

# %%
my_labels = my_kb.get_uploaded_labels()
print("Labelsets info : ")
print(my_labels)
print("Labelset: ", ", ".join(my_labels.keys()))
print("Labels:",", ".join(my_labels["reddit"].labels.keys()))
print("Tagged resources:",my_labels["reddit"].count)
my_vectorsets = my_kb.list_vectorset()
print("-----------------")
print("Vectorsets info : ")
print(my_vectorsets)
print("Vectorset: ", ", ".join(my_vectorsets.vectorsets.keys()))
print("Dimension:",", ",my_kb.list_vectorset().vectorsets["all-MiniLM-L6-v2"].dimension)
# Out:
# Labelsets info :
# {'reddit': LabelSet(count=10000, labels={'90DayFiance': 48, 'rpdrcringe': 47, 'TrollXChromosomes': 46, 'loveafterlockup': 46, 'nonononoyes': 44, 'ENLIGHTENEDCENTRISM': 43, 'teenagers': 43, 'NYYankees': 42, 'TeenMomOGandTeenMom2': 42, 'yesyesyesyesno': 42, 'atheism': 41, 'tifu': 41, 'SubredditSimulator': 40, 'Tinder': 40, 'entitledparents': 40, 'minnesotavikings': 40, 'Overwatch': 39, 'The_Mueller': 39, 'datingoverthirty': 39, 'sadcringe': 39, '2meirl4meirl': 38, 'Advice': 38, 'Blackops4': 38, 'Jokes': 38, 'SuicideWatch': 38, 'barstoolsports': 38, 'detroitlions': 38, 'exmormon': 38, 'unpopularopinion': 38, '90dayfianceuncensored': 37, 'Gunners': 37, 'OkCupid': 37, 'antiMLM': 37, 'confessions': 37, 'gaybros': 37, 'torontoraptors': 37, 'depression': 36, 'fatlogic': 36, 'heroesofthestorm': 36, 'AnimalsBeingBros': 35, 'CFB': 35, 'DoesAnybodyElse': 35, 'EdmontonOilers': 35, 'forwardsfromgrandma': 35, 'timberwolves': 35, 'Anarchism': 34, 'AnimalsBeingJerks': 34, 'Documentaries': 34, 'IncelTears': 34, 'JUSTNOMIL': 34})}
# Labelset:  reddit
# Labels: 90DayFiance, rpdrcringe, TrollXChromosomes, loveafterlockup, nonononoyes, ENLIGHTENEDCENTRISM, teenagers, NYYankees, TeenMomOGandTeenMom2, yesyesyesyesno, atheism, tifu, SubredditSimulator, Tinder, entitledparents, minnesotavikings, Overwatch, The_Mueller, datingoverthirty, sadcringe, 2meirl4meirl, Advice, Blackops4, Jokes, SuicideWatch, barstoolsports, detroitlions, exmormon, unpopularopinion, 90dayfianceuncensored, Gunners, OkCupid, antiMLM, confessions, gaybros, torontoraptors, depression, fatlogic, heroesofthestorm, AnimalsBeingBros, CFB, DoesAnybodyElse, EdmontonOilers, forwardsfromgrandma, timberwolves, Anarchism, AnimalsBeingJerks, Documentaries, IncelTears, JUSTNOMIL
# Tagged resources: 10000
# -----------------
# Vectorsets info :
# vectorsets={'all-MiniLM-L6-v2': VectorSet(dimension=384)}
# Vectorset:  all-MiniLM-L6-v2
# Dimension: ,  384

# %% [markdown]
# ## Filter by label
#
# Let's explore results from one of the subreddits.
# For that we filter by label, in this case `socialanxiety`

# %%
results = my_kb.search(
        filter=[Label(labelset="reddit", label="socialanxiety")]
    )
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
# Out:
# Text: Reading this made me pretty damn happy. Congrats hope it works out for you two.
# Labels: ['socialanxiety']
# Text: I don't drink at all specifically because the next day is sheer terror.
# Labels: ['socialanxiety']
# Text: Take a break then get back out there!
# Labels: ['socialanxiety']
# Text: I know how you feel :( I hope you start getting more good days soon. <3
# Labels: ['socialanxiety']
# Text: I always worry about my facial expressions. You're not alone there.
# Labels: ['socialanxiety']
# Text: Lol well if you see an awkward looking girl in a white car following at a safe distance, just know that’s little ole anxious me!
# Labels: ['socialanxiety']
# Text: I'd like to add spontaneously experiencing unending self-loathing because you suddenly remembered that embarrassing thing you did 3 years ago.
# Labels: ['socialanxiety']
# Text: Quitting porn only helped with my performance in bed, other than that I’m still anxious as hell in social spots
# Labels: ['socialanxiety']
# Text: also anxious that people will be angry or surprised or upset at me for me never telling people about this before
# Labels: ['socialanxiety']
# Text: In that conversation it was the girl being boring and closed... sometimes it’s not your fault and people feel they’re the ones being awkward
# Labels: ['socialanxiety']
# Text: People: Hey! Me: WHO ARE YOU AND WHAT DO YOU WANT FROM ME?!
# Labels: ['socialanxiety']
# Text: I feel like I lost focus... I have not accomplished anything and the clock isn't really stopping
# Labels: ['socialanxiety']
# Text: It involves a relationship with a girl so I need a girls input, sorry I’m not sexist or anything.
# Labels: ['socialanxiety']
# Text: The best feeling ever was when class was over and it never got to your turn, so you didnt have to present until the next day
# Labels: ['socialanxiety']
# Text: this strikes me hard. I wish i knew my way out of this
# Labels: ['socialanxiety']
# Text: I used to have anxiety when calling people but I no longer have them at least just 20-30% anxiety.
# Labels: ['socialanxiety']
# Text: Being misunderstood really is the worst thing ever! I’m sorry some people are so unkind.
# Labels: ['socialanxiety']
# Text: But... I really like taking a time for myself
# Labels: ['socialanxiety']
# Text: Yeah, people my age make me more anxious than older people. I feel like my generation is more judgmental.
# Labels: ['socialanxiety']
# Text: I'd just feel less out of place, I guess. My SA makes me feel like I'm so behind my peers in terms of a social life
# Labels: ['socialanxiety']

# %% [markdown]
# ## Text search
#
# Now let's try the full text search or keyword search.
#
# This search returns entries that contain the word or sets of words we input.
#
# First we'll look for developer and we will output the following fields for each result:
# - Text: Text of the matched results
# - Labels:  labels associated with the result, in this case the subreddit to which it belongs
# - Score: score of the result
# - Kind of score (BM25 for keyword search, Cosine similarity for semantic search)

# %%
results = my_kb.search(text="developer")
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
    print(f"Score: {result.score}")
    print(f"Score Type: {result.score_type}")
    print("------")
# Out:
# Text: It's just bizarre you would criticize [NAME] on his development capabilities when he's not a developer... His specialties are centered around crypto philosophy
# Labels: ['CryptoCurrency']
# Score: 6.545155048370361
# Score Type: BM25
# ------

# %% [markdown]
# Since we did not get many matches, we'll look for some more words related to technology:
# - Tech
# - Technology
# - Code

# %%
print("** tech")
results = my_kb.search(text="tech")
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
    
print("\n** technology")
results = my_kb.search(text="technology")
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")

print("\n** code")
results = my_kb.search(text="code")
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
# Out:
# ** tech
# Text: Damn. Low tech bait bike
# Labels: ['KidsAreFuckingStupid']
# Text: Yay! (Tech will be improved. Eeeek.)
# Labels: ['exchristian']
# Text: How many attempts did that insane tech take to pull off?
# Labels: ['CompetitiveForHonor']
# Text: Have nobody thought of the giant tech corporation selling overpriced, inferior products to sheep customers? That's odd.
# Labels: ['rickandmorty']
# Text: Have nobody thought of the giant tech corporation selling overpriced, inferior products to sheep customers? That's odd.
# Labels: ['rickandmorty']
#
# ** technology
# Text: I think there’s something to the concept that overindulgence in technology contributes to a lack of physical and emotional bonding these days.
# Labels: ['DeadBedrooms']
#
# ** code
# Text: And those offences are not Criminal Code offences. Criminal Code offences require it be established "beyond a reasonable doubt" that an accused actually committed the offence.
# Labels: ['ontario']
# Text: Don't give away my zip code! Craft beer and fabuloso be dammed!!
# Labels: ['Denver']
# Text: Because a lot of people on this thread are ignoring the pirate code and I’m trying to explain that rules are there for a reason.
# Labels: ['Seaofthieves']

# %% [markdown]
# Still not a lot of interesting results and some completely unrelated, so we'll move on to the semantic search

# %% [markdown]
# ## Vector search
#
# To get results that are related to the meaning of a word/sentence, we have our semantic search.
#
# This search will return the entries in our KB with higher cosine similarity to some given vectors.
#
# That is, the sentences that the model we use to create our vectors encodes as more similar to the one we are seraching for.
#
# To perfom this search, we  convert our desired query to vectors with the same model we used and input them to the search function.
#
# We need to use the field `vector` and we can add `min_score` if we want to define a minimun cosine similarity value for our results

# %%
query_vectors = encoder.encode(["Tech, devs, programming and coding"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2")
   
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
    print(f"Score: {result.score}")
    print(f"Key: {result.key}")
    print(f"Score Type: {result.score_type}")
    print("------")
# Out:
# Text: A lot of software guys are. Source: in software
# Labels: ['90dayfianceuncensored']
# Score: 0.48674964904785156
# Key: 0c0905cccf7f4591b4b57047a6efb858
# Score Type: COSINE
# ------
# Text: I have no idea what you’re talking about, so do you have carpentry experience and/or background in engineering?
# Labels: ['SubredditSimulator']
# Score: 0.3329728841781616
# Key: 5782d4cef8d24bfeba7cac074881c3fe
# Score Type: COSINE
# ------
# Text: What do you do for work?
# Labels: ['self']
# Score: 0.3191085159778595
# Key: a039b4cbfda0402b9e0db832ff56659b
# Score Type: COSINE
# ------
# Text: I want to be a rapper. I also like to write poetry and stuff. So to be successful with those things also I want to design clothing.
# Labels: ['SuicideWatch']
# Score: 0.30587318539619446
# Key: 565cfc551b814018b578742cfb454f65
# Score Type: COSINE
# ------
# Text: What is the job you are going to college for? Now days some jobs are more accepting with tattoos
# Labels: ['breakingmom']
# Score: 0.28778696060180664
# Key: 6f8ce8d396ec4b6cb4576fe09a02469e
# Score Type: COSINE
# ------
# Text: I can't wait for all these now unregulated projects to demonstrate why we had regulations in the first place.
# Labels: ['bestof']
# Score: 0.2871556580066681
# Key: 3088d8031b964d1aa50480bb0adaf71b
# Score Type: COSINE
# ------
# Text: As a former professional graphic designer, thank you for the gift of this subreddit.
# Labels: ['Blackfellas']
# Score: 0.28110983967781067
# Key: 99924a55cbcc4412a90c525ab59efd1b
# Score Type: COSINE
# ------
# Text: Stick to your arts degree, the men will keep building this province, regardless of having to fix garbage the TFWs built.
# Labels: ['alberta']
# Score: 0.2761256992816925
# Key: 1133939dcd2e4a81a73796add558064f
# Score Type: COSINE
# ------
# Text: Stick to your arts degree, the men will keep building this province, regardless of having to fix garbage the TFWs built.
# Labels: ['alberta']
# Score: 0.2761256992816925
# Key: a67feafb33ba499bb6252611b47c180a
# Score Type: COSINE
# ------
# Text: Correct! Unfortunately, we're looking for a bit more computing experience than knowing what site you're on. Thanks for your interest though.
# Labels: ['Calgary']
# Score: 0.274894654750824
# Key: f6feef4552d64e42b764894a3c034413
# Score Type: COSINE
# ------
# Text: [NAME], [NAME], [NAME], and [NAME] make a solid 2-5. We need a 1
# Labels: ['Browns']
# Score: 0.1897626519203186
# Key: 7a4dfe6bbe7b47908ea2555befebf031
# Score Type: COSINE
# ------
# Text: *blinded by the shill* I know like 2 people unfortunately..
# Labels: ['vanderpumprules']
# Score: 0.17885814607143402
# Key: eef7b96816b444ffa386a9a70a3c5593
# Score Type: COSINE
# ------
# Text: bored waiting for the game [NAME]
# Labels: ['Mavericks']
# Score: 0.1753552407026291
# Key: 7ec9c7be669f41ecbf6cd747c2df3af2
# Score Type: COSINE
# ------
# Text: It's a great time to be Scottish anaw
# Labels: ['LGBTeens']
# Score: 0.15197502076625824
# Key: 9959b5dee95a48e0adc4b30b70b561b5
# Score Type: COSINE
# ------
# Text: Does include bad cgi, tho?
# Labels: ['MortalKombat']
# Score: 0.15155920386314392
# Key: 21c0d0c0b0794a2ab7b87bfab0345acd
# Score Type: COSINE
# ------
# Text: I can’t work, wish I could. Worked hard my whole life and lost literally everything a few years ago. 20 years down the drain.
# Labels: ['SuicideWatch']
# Score: 0.1506510227918625
# Key: 3ccc3ccdbc314843b0affbaf6454d985
# Score Type: COSINE
# ------
# Text: What’s the chemical make up of a word? Yea thought so genius lmfaoooooo.
# Labels: ['unpopularopinion']
# Score: 0.12152998894453049
# Key: 1fce60fe2e5047018cca9d3a193e096f
# Score Type: COSINE
# ------
# Text: Or they just don't understand why cats do that with kittens.
# Labels: ['AnimalsBeingJerks']
# Score: 0.11862856894731522
# Key: 1efabe2b1a02443c83c06b9366127c27
# Score Type: COSINE
# ------
# Text: Plenty of places to build more damns in the WCape actually. Damn's are not the way forward? What do you propose?
# Labels: ['southafrica']
# Score: 0.11334880441427231
# Key: a182669224684ded9cd4088b88ec95c1
# Score Type: COSINE
# ------
# Text: Devastating and true.
# Labels: ['GenderCritical']
# Score: 0.11311877518892288
# Key: 3926115f2a60427ea39fb29f4057ebf3
# Score Type: COSINE
# ------

# %%
query_vectors = encoder.encode(["What is happiness"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2", min_score=0.15)
   
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
    print(f"Score: {result.score}")
    print(f"Key: {result.key}")
    print(f"Score Type: {result.score_type}")
    print("------")
# Out:
# Text: I’m a crybaby now, but I’m so happy to see happiness
# Labels: ['wholesomememes']
# Score: 0.5495570302009583
# Key: b5e69c7ecdf143ada0f914ad005ccf2f
# Score Type: COSINE
# ------
# Text: Ive never been happier and wouldnt want to live any other way
# Labels: ['AskMenOver30']
# Score: 0.5448427200317383
# Key: d292d3df7df14f65a924602392b809c9
# Score Type: COSINE
# ------
# Text: Happy just came out
# Labels: ['netflix']
# Score: 0.5028761029243469
# Key: f22e857832ca4fb0839772d35e1a9815
# Score Type: COSINE
# ------
# Text: You gotta make yourself happy when no one else does
# Labels: ['sadcringe']
# Score: 0.4969874322414398
# Key: 326099f6f2b947048cf2e1d7c888eca7
# Score Type: COSINE
# ------
# Text: I am happy for you. No, seriously, I am.
# Labels: ['drunk']
# Score: 0.4953000843524933
# Key: d8f2dd5ca5cb4ce3a5a1f055acd3b38c
# Score Type: COSINE
# ------
# Text: This. Making my animals happy is one of the only things that makes me happy.
# Labels: ['antinatalism']
# Score: 0.4914007782936096
# Key: 79a12b1b1e9e4d2ea3421f8862bf5a97
# Score Type: COSINE
# ------
# Text: more like consistent*winner*, i hope you find a lasting happiness
# Labels: ['confessions']
# Score: 0.4771484136581421
# Key: 5e90465d182f4e3cb6fbe3e8a146bafc
# Score Type: COSINE
# ------
# Text: I'm happy for you and myself.
# Labels: ['Conservative']
# Score: 0.4443480968475342
# Key: 64d0960b4c25439397dd65971176eb6c
# Score Type: COSINE
# ------
# Text: Thank you. I’ve been feeling a bit better since they make people happier.
# Labels: ['SuicideWatch']
# Score: 0.4405825734138489
# Key: 1d471953e008465a8644f5c015a06c92
# Score Type: COSINE
# ------
# Text: Thank you. I’ve been feeling a bit better since they make people happier.
# Labels: ['SuicideWatch']
# Score: 0.4405825734138489
# Key: a25876b953a54ebeb0aed92e0cb6cf54
# Score Type: COSINE
# ------
# Text: It's wonderful and gives me happy happy feels
# Labels: ['nrl']
# Score: 0.43432143330574036
# Key: 0ceb1371408c403da2b862037ccf43f0
# Score Type: COSINE
# ------
# Text: "I don't socialize because i'm unhappy and i'm unhappy because I don't socialize". -Socially anxious bastard
# Labels: ['socialanxiety']
# Score: 0.3679267466068268
# Key: 493320cf2335441ba73decae945a602e
# Score Type: COSINE
# ------
# Text: Such a sad way to think of life all because these people believe there's something greater than this.
# Labels: ['exmuslim']
# Score: 0.24923108518123627
# Key: 37885c7920a24160869f1143566084db
# Score Type: COSINE
# ------
# Text: Pfft why pay money when you can get similar negativity on reddit for free
# Labels: ['AFL']
# Score: 0.20185989141464233
# Key: b4cfd8283eb14d09a0367f1a679b64bd
# Score Type: COSINE
# ------
# Text: What’s the chemical make up of a word? Yea thought so genius lmfaoooooo.
# Labels: ['unpopularopinion']
# Score: 0.19069667160511017
# Key: 1fce60fe2e5047018cca9d3a193e096f
# Score Type: COSINE
# ------
# Text: Happy to hear this exciting news. Congratulations on your fun-filled morning.
# Labels: ['toronto']
# Score: 0.18980224430561066
# Key: 333192c4e6aa4ac4bff54c4191ae04f7
# Score Type: COSINE
# ------
# Text: This feeling is so bad
# Labels: ['mentalhealth']
# Score: 0.18853341042995453
# Key: bf523c2e6b4d40719799c8ab39fff821
# Score Type: COSINE
# ------
# Text: Feels good man
# Labels: ['Overwatch']
# Score: 0.18704958260059357
# Key: 30ab1216c7134b1dbc4ccce0fd530600
# Score Type: COSINE
# ------
# Text: Care to share your thought process ?
# Labels: ['walmart']
# Score: 0.16729246079921722
# Key: 36b00a5240ad43f2a923e510de6f9eb3
# Score Type: COSINE
# ------
# Text: bored waiting for the game [NAME]
# Labels: ['Mavericks']
# Score: 0.1580086350440979
# Key: 7ec9c7be669f41ecbf6cd747c2df3af2
# Score Type: COSINE
# ------

# %%
query_vectors = encoder.encode(["The meaning of life"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2", min_score=0.15)
   
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
    print(f"Score: {result.score}")
    print(f"Key: {result.key}")
    print(f"Score Type: {result.score_type}")
    print("------")
# Out:
# Text: iS thIs a MeTapHor FoR LifE?
# Labels: ['woooosh']
# Score: 0.6362201571464539
# Key: caa135337da744b2815edef6a23f1369
# Score Type: COSINE
# ------
# Text: So the key to living is to do nothing?
# Labels: ['philosophy']
# Score: 0.4603619873523712
# Key: 9b3423bc957e470b89b2f49fce498744
# Score Type: COSINE
# ------
# Text: Life is just an endless series of disappointments and no one gets out of here alive.
# Labels: ['INTP']
# Score: 0.447122722864151
# Key: 86999ab5865748cf8bfc3fcf08b53589
# Score Type: COSINE
# ------
# Text: Living his best life.
# Labels: ['cringe']
# Score: 0.4318602383136749
# Key: 315c9ef952634f6c922835de2662615c
# Score Type: COSINE
# ------
# Text: Living his best life.
# Labels: ['cringe']
# Score: 0.4318602383136749
# Key: cd010fb66c5742fcb93e39f2adf9c95e
# Score Type: COSINE
# ------
# Text: Why do you feel like you have to figure out what life is alone?
# Labels: ['confessions']
# Score: 0.42643851041793823
# Key: a002f3b28334454eb25562dd5d792009
# Score Type: COSINE
# ------
# Text: Such a sad way to think of life all because these people believe there's something greater than this.
# Labels: ['exmuslim']
# Score: 0.41576701402664185
# Key: 37885c7920a24160869f1143566084db
# Score Type: COSINE
# ------
# Text: It's when you least expect it that people hit you in the face with life It brings you back to earth
# Labels: ['TalesFromRetail']
# Score: 0.38056766986846924
# Key: a54844773fc24444b256d9f950334e72
# Score Type: COSINE
# ------
# Text: Story of my life
# Labels: ['MakingaMurderer']
# Score: 0.3753337562084198
# Key: 08e992fe44c840e2a1ff89dd687cf1d2
# Score Type: COSINE
# ------
# Text: I’m curious about the chain of life events and choices that could land someone at this point in life
# Labels: ['awfuleverything']
# Score: 0.36847200989723206
# Key: d47eecef875f4bb5a883c83c2a8cfe53
# Score Type: COSINE
# ------
# Text: You live for it, it's the only reason you're here.
# Labels: ['ukpolitics']
# Score: 0.3423509895801544
# Key: a325d75c056e41aa817260c41b77ec2c
# Score Type: COSINE
# ------
# Text: bored waiting for the game [NAME]
# Labels: ['Mavericks']
# Score: 0.25379377603530884
# Key: 7ec9c7be669f41ecbf6cd747c2df3af2
# Score Type: COSINE
# ------
# Text: Care to share your thought process ?
# Labels: ['walmart']
# Score: 0.2537767291069031
# Key: 36b00a5240ad43f2a923e510de6f9eb3
# Score Type: COSINE
# ------
# Text: I'm sure that's a really important issue to you that consumes your daily life...
# Labels: ['Wellthatsucks']
# Score: 0.22401809692382812
# Key: 4265ae933fd24b54a20efa1b60dd38dd
# Score Type: COSINE
# ------
# Text: I mean I'm genuinely not sure if I'd rather be tortured for all eternity or have to spend all eternity in Sunday services
# Labels: ['gay_irl']
# Score: 0.20082761347293854
# Key: 60d589a05cfe45ae8012f8d6cc94474c
# Score Type: COSINE
# ------
# Text: This post fucking sucks because it doesn't cater to my beliefs.
# Labels: ['weezer']
# Score: 0.1984260231256485
# Key: 0d26387b24834e9699541e83a0ccdd4f
# Score Type: COSINE
# ------
# Text: Feels good man
# Labels: ['Overwatch']
# Score: 0.17689864337444305
# Key: 30ab1216c7134b1dbc4ccce0fd530600
# Score Type: COSINE
# ------
# Text: This feeling is so bad
# Labels: ['mentalhealth']
# Score: 0.1707349270582199
# Key: bf523c2e6b4d40719799c8ab39fff821
# Score Type: COSINE
# ------
# Text: So thoughtful.
# Labels: ['houston']
# Score: 0.1641416698694229
# Key: d3356ac11b72478cad74135d28a4cad9
# Score Type: COSINE
# ------
# Text: >!why you bully me :,0 i didn't even know what a mantis was before this conversation!<
# Labels: ['danganronpa']
# Score: 0.16047266125679016
# Key: 3f710cd871d24ea4bdd64fe8dcfee8fe
# Score Type: COSINE
# ------

# %%
query_vectors = encoder.encode(["What is love?"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2", min_score=0.15)
   
for result in results:
    print(f"Text: {result.text}")
    print(f"Labels: {result.labels}")
    print(f"Score: {result.score}")
    print(f"Key: {result.key}")
    print(f"Score Type: {result.score_type}")
    print("------")
# Out:
# Text: Love has no number
# Labels: ['teenagers']
# Score: 0.4977535605430603
# Key: f858239f65ac4556b6a19228874b6dbc
# Score Type: COSINE
# ------
# Text: “Love” under threat of execution. Wow.
# Labels: ['IncelTears']
# Score: 0.47561562061309814
# Key: 8c72856d170a4e52857511a76440ad0d
# Score Type: COSINE
# ------
# Text: “Love” under threat of execution. Wow.
# Labels: ['IncelTears']
# Score: 0.47561562061309814
# Key: 9017abc48df74adabe3f1215bdc0b2db
# Score Type: COSINE
# ------
# Text: I love you. I had no idea before now, but I love you.
# Labels: ['TIHI']
# Score: 0.453585147857666
# Key: dec4561f48e44f188453ed51b701406e
# Score Type: COSINE
# ------
# Text: Pure unconsitional love can also be dangerous: if the other person turns out to be an abuser you should propably stop loving them
# Labels: ['AskMen']
# Score: 0.44075626134872437
# Key: 9b7764040515468281a38bc2db23e835
# Score Type: COSINE
# ------
# Text: Or a lovegod That supports you
# Labels: ['Tinder']
# Score: 0.4096187949180603
# Key: 79395bc8cff14f06abe4af1ee7d5f825
# Score Type: COSINE
# ------
# Text: There is obviously love here. Don’t give up. Talk to each other.
# Labels: ['DeadBedrooms']
# Score: 0.39207711815834045
# Key: 497dcf6f387b4c16b3ccd9bd4648b68d
# Score Type: COSINE
# ------
# Text: Gotta love [NAME].
# Labels: ['Music']
# Score: 0.3871612548828125
# Key: 1eb666052aff42d0943065f9e26934fa
# Score Type: COSINE
# ------
# Text: Dear [NAME], **DON'T FUCK THIS UP** Love, Me
# Labels: ['denvernuggets']
# Score: 0.383357971906662
# Key: 772ce1be1dc94dbe9258efe05479002d
# Score Type: COSINE
# ------
# Text: Peace and love, my brother!
# Labels: ['UpliftingNews']
# Score: 0.37950992584228516
# Key: fe1cb6be75034be6a27b6e693ef4e441
# Score Type: COSINE
# ------
# Text: This feeling is so bad
# Labels: ['mentalhealth']
# Score: 0.25207918882369995
# Key: bf523c2e6b4d40719799c8ab39fff821
# Score Type: COSINE
# ------
# Text: What’s the chemical make up of a word? Yea thought so genius lmfaoooooo.
# Labels: ['unpopularopinion']
# Score: 0.24673177301883698
# Key: 1fce60fe2e5047018cca9d3a193e096f
# Score Type: COSINE
# ------
# Text: When my mom yells at me like that is because she loves me though, she should learn something from this
# Labels: ['rupaulsdragrace']
# Score: 0.24328026175498962
# Key: 087f7f77551c4024b6a4f5e11071c1d0
# Score Type: COSINE
# ------
# Text: Care to share your thought process ?
# Labels: ['walmart']
# Score: 0.23389357328414917
# Key: 36b00a5240ad43f2a923e510de6f9eb3
# Score Type: COSINE
# ------
# Text: Feels good man
# Labels: ['Overwatch']
# Score: 0.22921708226203918
# Key: 30ab1216c7134b1dbc4ccce0fd530600
# Score Type: COSINE
# ------
# Text: I think it’s [NAME]
# Labels: ['SweatyPalms']
# Score: 0.16811604797840118
# Key: 6ea8d24cab98462f9628619907a76a14
# Score Type: COSINE
# ------
# Text: Devastating and true.
# Labels: ['GenderCritical']
# Score: 0.16414493322372437
# Key: 3926115f2a60427ea39fb29f4057ebf3
# Score Type: COSINE
# ------
# Text: Are you confessing to not being able to understand what this sub is about?
# Labels: ['confession']
# Score: 0.16364558041095734
# Key: 39dbe5a039024ef49871e12b64cdec2e
# Score Type: COSINE
# ------
# Text: So thoughtful.
# Labels: ['houston']
# Score: 0.15654700994491577
# Key: d3356ac11b72478cad74135d28a4cad9
# Score Type: COSINE
# ------
# Text: Hi [NAME], I love you, that is all. Can't wait to see you in Worcester in February!
# Labels: ['Music']
# Score: 0.15364748239517212
# Key: 49f0cba3d2144c15a90a4d94d38744ad
# Score Type: COSINE
# ------

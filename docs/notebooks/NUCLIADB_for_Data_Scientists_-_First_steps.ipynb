# %%
import os
import requests
from nucliadb_sdk.knowledgebox import KnowledgeBox
from nucliadb_sdk.labels import Label
from nucliadb_sdk.utils import create_knowledge_box, get_or_create
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Setup
#
# Make sure we've started **NucliaDB's container**
#
# ```
# docker run -it \
#        -e LOG=INFO \
#        -p 8080:8080 \
#        -p 8060:8060 \
#        -p 8040:8040 \
#        -v nucliadb-standalone:/data \
#        nuclia/nucliadb:latest
# ```
# Then, we'll check the connection:

# %%
response = requests.get(f"http://localhost:8080")
assert response.ok

# %% [markdown]
# ## Setup - creating a KB
#
# In nucliadb our data containers are called knowledge boxes.
#
# To start working, we need to create one:
#
# *We create it with the function get_or_create so that it won't be created again if it exists*

# %%
my_kb = get_or_create("my_reddit_data_kb")

# %% [markdown]
# ## Setup - preparing data & model
#
# We download our dataset and the sentence embedding model we are going to use

# %%
from datasets import load_dataset
dataset = load_dataset("go_emotions", "raw")

sample = dataset["train"].shuffle().select(range(10000))
# Out:
# Found cached dataset go_emotions (/Users/ciniesta/.cache/huggingface/datasets/go_emotions/raw/0.0.0/2637cfdd4e64d30249c3ed2150fa2b9d279766bfcd6a809b9f085c61a90d776d)
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 19.12it/s]

# %%
encoder = SentenceTransformer("all-MiniLM-L6-v2")

# %% [markdown]
# ## Uploading data to our KB
#
# we use the upload function to index text, labels and calculated vectors for each sentence of our dataset.
# Tips:
# - We can have more than one set of vectors in our data, just add another entry to the vectors dict `vectors={"roberta-vectors": vectors-roberta,"bert-vectors": vectors-bert }`
# - If you want to avoid uploading the same data twice by mistake, just add a `key` to your upload, its an unique identifier and it will update the resources when uploading them again instead of duplicating them. `key="my_reddit_sample"`

# %%
for row in sample:
    label = row["subreddit"]
    my_kb.upload(
        text=row["text"],
        labels=[f"reddit/{label}"],
        vectors={"all-MiniLM-L6-v2": encoder.encode([row["text"]])[0].tolist()},
    )
# Out:
# Vectorset is not created, we will create it for you

# %% [markdown]
# ## Checks
#
# We uploaded only data with one label.
# But we could have added more if we had code from other modules, or if we wanted to label some other code features
#
# Let's check if the numbers agree!

# %%
my_labels = my_kb.get_uploaded_labels()
print("Labelsets info : ")
print(my_labels)
print("Labelset: ", ", ".join(my_labels.keys()))
print("Labels:",", ".join(my_labels["reddit"].labels.keys()))
print("Tagged resources:",my_labels["reddit"].count)
my_vectorsets = my_kb.list_vectorset()
print("-----------------")
print("Vectorsets info : ")
print(my_vectorsets)
print("Vectorset: ", ", ".join(my_vectorsets.vectorsets.keys()))
print("Dimension:",", ",my_kb.list_vectorset().vectorsets["all-MiniLM-L6-v2"].dimension)
# Out:
# Labelsets info :
# {'reddit': LabelSet(count=10000, labels={'socialanxiety': 48, 'danganronpa': 47, 'loveafterlockup': 47, '90DayFiance': 43, 'Blackops4': 43, 'Marriage': 43, 'devils': 43, 'AnimalsBeingBros': 42, 'TheSimpsons': 42, 'gaybros': 42, 'videos': 42, 'wholesomememes': 42, '4PanelCringe': 41, 'OkCupid': 41, 'ProtectAndServe': 41, 'rant': 40, 'tifu': 40, 'traaaaaaannnnnnnnnns': 40, 'TeenMomOGandTeenMom2': 39, 'saltierthancrait': 39, 'timberwolves': 39, 'Dodgers': 38, 'DunderMifflin': 38, 'NYGiants': 38, 'NYYankees': 38, 'relationship_advice': 38, 'teenagers': 38, 'Advice': 37, 'AnimalsBeingJerks': 37, 'Artifact': 37, 'Mavericks': 37, 'WeWantPlates': 37, 'deadbydaylight': 37, 'morbidquestions': 37, 'youseeingthisshit': 37, 'AskMen': 36, 'ChoosingBeggars': 36, 'MaliciousCompliance': 36, 'Scotland': 36, 'SubredditSimulator': 36, 'TheWalkingDeadGame': 36, 'askwomenadvice': 36, 'cringe': 36, 'minnesotavikings': 36, 'nonononoyes': 36, 'rpdrcringe': 36, 'sadcringe': 36, 'ComedyCemetery': 35, 'Conservative': 35, 'DiWHY': 35})}
# Labelset:  reddit
# Labels: socialanxiety, danganronpa, loveafterlockup, 90DayFiance, Blackops4, Marriage, devils, AnimalsBeingBros, TheSimpsons, gaybros, videos, wholesomememes, 4PanelCringe, OkCupid, ProtectAndServe, rant, tifu, traaaaaaannnnnnnnnns, TeenMomOGandTeenMom2, saltierthancrait, timberwolves, Dodgers, DunderMifflin, NYGiants, NYYankees, relationship_advice, teenagers, Advice, AnimalsBeingJerks, Artifact, Mavericks, WeWantPlates, deadbydaylight, morbidquestions, youseeingthisshit, AskMen, ChoosingBeggars, MaliciousCompliance, Scotland, SubredditSimulator, TheWalkingDeadGame, askwomenadvice, cringe, minnesotavikings, nonononoyes, rpdrcringe, sadcringe, ComedyCemetery, Conservative, DiWHY
# Tagged resources: 10000
# -----------------
# Vectorsets info :
# vectorsets={'all-MiniLM-L6-v2': VectorSet(dimension=384)}
# Vectorset:  all-MiniLM-L6-v2
# Dimension: ,  384

# %% [markdown]
# ## Filter by label
#
# Let's explore results from one of the subreddits

# %%
results = my_kb.search(
        filter=[Label(labelset="reddit", label="socialanxiety")]
    )
for result in results:
    print(result.text)
    print(result.labels)
# Out:
# hello there, i sent some hugs your way. ^.^
# ['socialanxiety']
# Write down the problems and how you feel when and after you have them. Then take that to therapy and actually get vulnerable with your therapist.
# ['socialanxiety']
# Hell yeah, high five. Good job!
# ['socialanxiety']
# Yeah i miss lectures for this exact reason. Its pretty bad, but what can ya do :/
# ['socialanxiety']
# Hell yeah, high five. Good job!
# ['socialanxiety']
# Reading this made me pretty damn happy. Congrats hope it works out for you two.
# ['socialanxiety']
# Hey, I love you! 😁
# ['socialanxiety']
# Yeah i miss lectures for this exact reason. Its pretty bad, but what can ya do :/
# ['socialanxiety']
# Congrats. Having a steady job (and one that I actually enjoy somewhat) is the #1 thing that helped me out with depression/anxiety.
# ['socialanxiety']
# It developed because of my childhood and robbed me of a good bit of good stuff as an adult.
# ['socialanxiety']
# Thank you :) I'll try to stay positive
# ['socialanxiety']
# Sameee, if I got a dollar for every time I’ve gotten that comment I’d be able to end world hunger
# ['socialanxiety']
# They have problems for sure.But they don't have YOUR problems.
# ['socialanxiety']
# Every time without fail
# ['socialanxiety']
# That's great! You got this!
# ['socialanxiety']
# I know but it just sucks to feel like this
# ['socialanxiety']
# You can wait ten years to start working on yourself and get what you want or you can do it now.
# ['socialanxiety']
# Boom! Thank you I’m going to check out your Channel
# ['socialanxiety']
# I have no friends.
# ['socialanxiety']
# Pretty blunt/rude on his part. Maybe he felt bad for you and wanted to be your friend though.
# ['socialanxiety']

# %% [markdown]
# ## Text search
#
# Now let's try the full text search

# %%
results = my_kb.search(text="developer")
for result in results:
    print(result.text)
    print(result.labels)
    print(result.score)
    print(result.key)
    print(result.score_type)
    print("------")
# Out:
# It's just bizarre you would criticize [NAME] on his development capabilities when he's not a developer... His specialties are centered around crypto philosophy
# ['CryptoCurrency']
# 5.891018390655518
# 8cf5c77655264ef081e840043bb5ec41
# ScoreType.BM25
# ------
# It's just bizarre you would criticize [NAME] on his development capabilities when he's not a developer... His specialties are centered around crypto philosophy
# ['CryptoCurrency']
# 5.891018390655518
# 0517466b9e4c4ec8afabd2e539c235f7
# ScoreType.BM25
# ------
# I'm kinda in this same boat as OP and currently learning to code to become a web developer. Wondering if this field is compatible with ASD .
# ['aspergers']
# 5.637315273284912
# 4279a693878645c8aeb778d74d48b7fc
# ScoreType.BM25
# ------

# %%
results = my_kb.search(text="tech")
for result in results:
    print(result.text)
    print(result.labels)
    
results = my_kb.search(text="technology")
for result in results:
    print(result.text)
    print(result.labels)
    
results = my_kb.search(text="code")
for result in results:
    print(result.text)
    print(result.labels)
    
results = my_kb.search(text="tech")
for result in results:
    print(result.text)
    print(result.labels)
# Out:
# Damn. Low tech bait bike
# ['KidsAreFuckingStupid']
# Key that we keep welcoming ~~young~~ international tech talent to London.
# ['london']
# Sitting at home drunk waiting for my tech to charge so I can sit out back and listen to music lol
# ['drunk']
# Technology is amazing. Now we can SEE how new plagues start. Just incredible.
# ['AnimalsBeingBros']
# Maybe because those are real, tangible things and not lines of code
# ['SubredditDrama']
# What do you mean? It would be the same code for every system?
# ['instant_regret']
# What do you mean? It would be the same code for every system?
# ['instant_regret']
# How does ones SO even go through your ph ? Mine is locked with a pass code and a finger print
# ['adultery']
# Because a lot of people on this thread are ignoring the pirate code and I’m trying to explain that rules are there for a reason.
# ['Seaofthieves']
# Because a lot of people on this thread are ignoring the pirate code and I’m trying to explain that rules are there for a reason.
# ['Seaofthieves']
# I'm kinda in this same boat as OP and currently learning to code to become a web developer. Wondering if this field is compatible with ASD .
# ['aspergers']
# Damn. Low tech bait bike
# ['KidsAreFuckingStupid']
# Key that we keep welcoming ~~young~~ international tech talent to London.
# ['london']
# Sitting at home drunk waiting for my tech to charge so I can sit out back and listen to music lol
# ['drunk']

# %% [markdown]
# ## Vector search
#
# Now we perform semantic search.
# To do so, we just convert our query to vectors with the same model we used and use the search function
# We need to use the field `vector` and we can use `min_score`if we want to define a minimun cosine similarity value for our results

# %%
query_vectors = encoder.encode(["Tech, developers, programming and coding"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2", min_score=0.15)
   
for result in results:
    print(result.text)
    print(result.labels)
    print(result.score)
    print(result.key)
    print(result.score_type)
    print("------")
# Out:
# Yeah, if companies really wanted to ameliorate the lack of programmers they could hire and train more juniors, but that doesn't benefit them much.
# ['TrueReddit']
# 0.42079004645347595
# 6609af856e8449f6b8f03962fe9ae66d
# ScoreType.COSINE
# ------
# You are terrible developers.
# ['TownofSalemgame']
# 0.39345312118530273
# db673044c06e49fe9e764c7cc403d03b
# ScoreType.COSINE
# ------
# You are terrible developers.
# ['TownofSalemgame']
# 0.39345312118530273
# ed9fa918d76a497e9b69f31809eedd26
# ScoreType.COSINE
# ------
# Where do you work/what do you do?
# ['rant']
# 0.3706532120704651
# a28255cc49154a9084fc99f4d8bcdc99
# ScoreType.COSINE
# ------
# I mean, who doesnt? But youre right, techgore is not the place for it.
# ['lostredditors']
# 0.36273515224456787
# a314e87cbbcc4d9db4b82d661ccb7140
# ScoreType.COSINE
# ------
# I work at an R1 university, with most of my team composed of CS/CE undergrad students. Yes, I've known many...
# ['OutOfTheLoop']
# 0.35480910539627075
# c0fb23c7ff554fa59e7cf74cd702cc1c
# ScoreType.COSINE
# ------
# Maybe because those are real, tangible things and not lines of code
# ['SubredditDrama']
# 0.3347686231136322
# 068da4b2fbdb42ebbd1b1c10d214181a
# ScoreType.COSINE
# ------
# A TECHNICAL Lmao.
# ['GoNets']
# 0.33313125371932983
# a4332df549cf40e0b353bed4656b6d2d
# ScoreType.COSINE
# ------
# hum yhea i kind of agree, but i still dont understand what it has to do with the amount of devs left working on the game.
# ['StarWarsBattlefront']
# 0.33118510246276855
# 8f1c946482854c188510ebd01443e00a
# ScoreType.COSINE
# ------
# Likely some more bitching about easily fixable features being swept under the rug by employees
# ['CODZombies']
# 0.3305935263633728
# 99759a7d5a174a9f8f0e4d37e49ff4ac
# ScoreType.COSINE
# ------
# Lol. Yes, the contractors know
# ['AskThe_Donald']
# 0.2265336811542511
# f284865a7e3b4f49b3ffe66d4cc6c0c1
# ScoreType.COSINE
# ------
# Fuck I laughed at this post :D You better stick to your words and make sure to Tag every BF:V Dev.
# ['BattlefieldV']
# 0.21605603396892548
# 73868bda09e7436490b021ab3f8ae8be
# ScoreType.COSINE
# ------
# Yep...this sub blasted me for hating the casey hire and still refuses to admit his big faults
# ['DetroitPistons']
# 0.18045595288276672
# 7d7f2decdcc349b2820a0210a209cd02
# ScoreType.COSINE
# ------
# I'm pretty sure the IT guy was instructed to put the site down with not much more instructions.
# ['QuadrigaCX']
# 0.17824825644493103
# 6af9a8f3241a4d43a54bc12b60f29b81
# ScoreType.COSINE
# ------
# We need more boards and to create a bit more space for [NAME]. Then we’ll be good.
# ['MkeBucks']
# 0.1639900505542755
# 138645982bb545dbb173433134b31b9b
# ScoreType.COSINE
# ------
# Treyarch: adds all blackout servers to South America [NAME]: OMG treyarch why does matchmaking take so long.
# ['Blackops4']
# 0.16333158314228058
# e2fa22d3c6dd47b0934a65424f92cfbf
# ScoreType.COSINE
# ------
# Don’t forget to show your work!
# ['pettyrevenge']
# 0.15160834789276123
# 1c16d5cd88ae437b87977776e9249860
# ScoreType.COSINE
# ------

# %%
query_vectors = encoder.encode(["What is happiness"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2", min_score=0.15)
   
for result in results:
    print(result.text)
    print(result.labels)
    print(result.score)
    print(result.key)
    print(result.score_type)
    print("------")
# Out:
# Money can't buy me happiness...
# ['2meirl4meirl']
# 0.6215714812278748
# 9e070c12f4b34d5a876ac39971325668
# ScoreType.COSINE
# ------
# Me, for example. I am very very happy.
# ['FrankOcean']
# 0.5764293670654297
# 5c3e0a1369fa4b9695d472d2f711b97c
# ScoreType.COSINE
# ------
# Emotions are temporary. That's why we have multiple different ones. If you were permanently happy, you'd never feel sadness or envy or anger again.
# ['Drugs']
# 0.5472765564918518
# 5f67a5d2ecf84140ba22c36baf32fdaf
# ScoreType.COSINE
# ------
# Apathetic. Not happy, not sad, just don't care
# ['Jokes']
# 0.5173780918121338
# ce587828dfad443182c59841ae0ee6e9
# ScoreType.COSINE
# ------
# I am happy for you. No, seriously, I am.
# ['drunk']
# 0.4953000843524933
# dd87d424c0064e278b9eadaa6f65d1c1
# ScoreType.COSINE
# ------
# I hope that you find happiness, too. I'm happy that you've had a place to vent.
# ['depression']
# 0.48470982909202576
# b6f1fe0a6e974840a6fe104378db2d62
# ScoreType.COSINE
# ------
# Be happy because I won't be short anymore one day
# ['danganronpa']
# 0.4442950189113617
# 6bb953530cc5404c9420ff83cc81cfa5
# ScoreType.COSINE
# ------
# [NAME] IS SMILING EVERYONE
# ['torontoraptors']
# 0.4390324056148529
# 6cfb16353cd04b7d9330324f69fb78e0
# ScoreType.COSINE
# ------
# Fake smile always gives dopamine/happiness to deal with stress
# ['socialanxiety']
# 0.4380534291267395
# 0759a62dbf6c493a805d8a6252874615
# ScoreType.COSINE
# ------
# I don't drink I don't smoke I don't do drugs and yet still am not "happy rich and all that people say this brings"
# ['GetMotivated']
# 0.43795594573020935
# a6a960766ca44556bbbb2dc4bdbe0eab
# ScoreType.COSINE
# ------
# To much of a good thing is a bad thing
# ['entitledparents']
# 0.27828359603881836
# 8e9ada50659a42cb8a6004d4f6836552
# ScoreType.COSINE
# ------
# It's just sad; she was just nice and normal before she messed with her looks
# ['Instagramreality']
# 0.2039576768875122
# 5675a2788a2b4bd180f69d389d1216a0
# ScoreType.COSINE
# ------
# We've allways a ear to rent you here in reddit, you little sensitive bigheart. Now time to feel good again, ok?
# ['confession']
# 0.20203617215156555
# 191c6a755ba4450da9ada201bc6eabda
# ScoreType.COSINE
# ------
# This one is sad but also very good
# ['TwoSentenceHorror']
# 0.19825156033039093
# 37f20ed33d464b098221833092ee2272
# ScoreType.COSINE
# ------
# You look the same to me, but I'm happy you had a goal and accomplished it!! You're a cutie !!
# ['IncelsWithoutHate']
# 0.1941768079996109
# 1a00cc88043847db946d33c5f80e05c4
# ScoreType.COSINE
# ------
# Appreciate the love man!! It's a fun game!
# ['Blackops4']
# 0.1907840371131897
# a02a2b01891d4e4c9b461a880fca08b0
# ScoreType.COSINE
# ------
# “Brave” is one way of describing it
# ['LabourUK']
# 0.17751653492450714
# 7697c54d4dc3492d92c0fbfe159b12b6
# ScoreType.COSINE
# ------
# Thank you very much. Follow up question what is a suura?
# ['TooAfraidToAsk']
# 0.17453815042972565
# b786f9beb00c41f5b0fce234fb70c3fe
# ScoreType.COSINE
# ------
# Problem is we don't have much else of value. [NAME], [NAME], [NAME]. We have to hope [NAME] likes THJ.
# ['NYKnicks']
# 0.17165140807628632
# e946f13311194fbcb901a92dcf3fa4f9
# ScoreType.COSINE
# ------
# It was SO hard to click the upvote button on this one. It's one of those "I hate it. Well done" moments.
# ['antiMLM']
# 0.1694078892469406
# e4b4771233804a07acd367b80c433d04
# ScoreType.COSINE
# ------

# %%
query_vectors = encoder.encode(["The meaning of life"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2", min_score=0.15)
   
for result in results:
    print(result.text)
    print(result.labels)
    print(result.score)
    print(result.key)
    print(result.score_type)
    print("------")
# Out:
# There is no *inherent* meaning, but this does not necessarily render it meaningless. Only you can decide whether your life has meaning or not.
# ['DebateAnAtheist']
# 0.6319499015808105
# eec5ea268fa8472d8fd7c858e87606b0
# ScoreType.COSINE
# ------
# Is this the real life?
# ['4PanelCringe']
# 0.4298684000968933
# 5cc64354c59845b8a5259363fa7c41b7
# ScoreType.COSINE
# ------
# Such a sad way to think of life all because these people believe there's something greater than this.
# ['exmuslim']
# 0.41576701402664185
# 48a482ac93904e149cb24e6d5b6e8cf3
# ScoreType.COSINE
# ------
# A life well spent....
# ['videos']
# 0.396190881729126
# 7c024dbe0da74392a54550ddb105d7ee
# ScoreType.COSINE
# ------
# My life!
# ['conspiracy']
# 0.390045166015625
# 26b32d31a45a45d9899c7ab080cf6ad3
# ScoreType.COSINE
# ------
# I'm going to put my life first and run away.
# ['rant']
# 0.35358867049217224
# a3b4ac8c082846b8938fdc808369eabb
# ScoreType.COSINE
# ------
# Ah the high life. Must be sweet.
# ['ProtectAndServe']
# 0.346894234418869
# 4ee21622d92f4788a2feaf17707c405e
# ScoreType.COSINE
# ------
# Life is Strange is terrible. Absolutely zero gameplay...
# ['pcgaming']
# 0.3414113521575928
# d1e67931b7ab457e8feab178fb7d3fa2
# ScoreType.COSINE
# ------
# Life will always get better regardless of ones situation or condition or whatever, life will indeed get better. It might take a while but it will.
# ['TooAfraidToAsk']
# 0.34040579199790955
# c0516a6efd0e4538990a5b3c7ebca5e1
# ScoreType.COSINE
# ------
# Punchy is Life <3
# ['Games']
# 0.3346041738986969
# bf1c3187eab847feb91c8ab3f7481d64
# ScoreType.COSINE
# ------
# I want to die
# ['TIHI']
# 0.2600064277648926
# 5c3b095d6ede4af8bd5e4e523546dde9
# ScoreType.COSINE
# ------
# Free will is about not having to justify everything you do. It's about spontaneity. It's about doing things just because.
# ['samharris']
# 0.2558198869228363
# 6543625dac364e16a27d2e1cbfb6a5e3
# ScoreType.COSINE
# ------
# I made some super dumb decisions as a teen. Thankfully nothing life affecting. Source: was teen
# ['KidsAreFuckingStupid']
# 0.22431370615959167
# 806ac2b17cf64e2d84a9af61b50d5ba5
# ScoreType.COSINE
# ------
# Hey daddy [NAME]
# ['NYGiants']
# 0.21141605079174042
# d94b3d33d9dd4d79a6f5e40626534b71
# ScoreType.COSINE
# ------
# This!!! This!!! Is the definition of a choosy beggar. You give a hand and they want your arm.
# ['ChoosingBeggars']
# 0.19904367625713348
# 6177c14e459442be9c38b8bd532deffa
# ScoreType.COSINE
# ------
# I would choose to go in the coolest way possible. Don’t know what that would be but I would want my last moments to be memorable.
# ['Documentaries']
# 0.19750113785266876
# c7c48d03603244e08b15cdef91d2e051
# ScoreType.COSINE
# ------
# Tell me why it’s not wholesome so I can figure out how to reply in a way you understand
# ['lostredditors']
# 0.19403059780597687
# 47d3eb2c32f3426292d5cba7ba35acbc
# ScoreType.COSINE
# ------
# Step 1: Stop thinking socialism is a lifestyle.
# ['socialism']
# 0.17606206238269806
# a672eb5500344e79a37682571f5290ed
# ScoreType.COSINE
# ------
# I'd rather die than drive a Volvo!
# ['Truckers']
# 0.17541654407978058
# a4dfdae6bd8247908ab84eb785ac2f2b
# ScoreType.COSINE
# ------
# We weren't just husband and wife, we were best friends (i thought)
# ['Marriage']
# 0.17135965824127197
# d98f0422958a4ff184f5bba9135d277d
# ScoreType.COSINE
# ------

# %%
query_vectors = encoder.encode(["What is love?"])[0].tolist()
results = my_kb.search(vector = query_vectors, vectorset="all-MiniLM-L6-v2", min_score=0.15)
   
for result in results:
    print(result.text)
    print(result.labels)
    print(result.score)
    print(result.key)
    print(result.score_type)
    print("------")
# Out:
# I would say love is never enough. Love is unconditional. Relationships are not.
# ['polyamory']
# 0.5383067727088928
# 32851600b3924d5e808ea7d6fab71c36
# ScoreType.COSINE
# ------
# Love has no number
# ['teenagers']
# 0.4977535605430603
# b1d809a8dc004b7588f1bc932174925b
# ScoreType.COSINE
# ------
# Love has no number
# ['teenagers']
# 0.4977535605430603
# d0c05c5f565049b7a216407b63389db5
# ScoreType.COSINE
# ------
# [NAME] loves (the taste of) people
# ['AnimalsBeingBros']
# 0.4653770923614502
# 1ff3e1bffe284275965c946aece7d429
# ScoreType.COSINE
# ------
# I love you. I had no idea before now, but I love you.
# ['TIHI']
# 0.453585147857666
# 9ceb5619df1043ccbaced517b714dcb3
# ScoreType.COSINE
# ------
# And also something against [NAME]. (My definition of [NAME] is just people at the bottom of love distribution)
# ['IncelsWithoutHate']
# 0.44246917963027954
# b8f79e9b1bff4e538b649cfcf5e74e6f
# ScoreType.COSINE
# ------
# Don't judge our love
# ['COMPLETEANARCHY']
# 0.431450754404068
# ee5ba51c526b4e368cdcb134385b4cc7
# ScoreType.COSINE
# ------
# Or a lovegod That supports you
# ['Tinder']
# 0.4096187949180603
# 66edfea0e5dc4b97bd88178be52d965e
# ScoreType.COSINE
# ------
# As someone who has been in a similar relationship, it is indeed emotional abuse.
# ['sadcringe']
# 0.4056171178817749
# 030b3208aadd4af493d8f9f288d56dd8
# ScoreType.COSINE
# ------
# I guess but we love each other.
# ['relationships']
# 0.40363046526908875
# 9d2dfa0ad9494e469cfb8adc036cc6da
# ScoreType.COSINE
# ------
# Appreciate the love man!! It's a fun game!
# ['Blackops4']
# 0.3136330246925354
# a02a2b01891d4e4c9b461a880fca08b0
# ScoreType.COSINE
# ------
# They are a couple in love so what's your beef.
# ['GCdebatesQT']
# 0.2920997440814972
# fbc5007fb3ab41febabffe05ebd7de48
# ScoreType.COSINE
# ------
# We weren't just husband and wife, we were best friends (i thought)
# ['Marriage']
# 0.2458370178937912
# d98f0422958a4ff184f5bba9135d277d
# ScoreType.COSINE
# ------
# Nobody knows. Lurk more.
# ['doordash']
# 0.24447046220302582
# a4077b167b644e1fb71f8bf89fb8292f
# ScoreType.COSINE
# ------
# Tell me why it’s not wholesome so I can figure out how to reply in a way you understand
# ['lostredditors']
# 0.21337278187274933
# 47d3eb2c32f3426292d5cba7ba35acbc
# ScoreType.COSINE
# ------
# Haha okay. Much love brother!
# ['Gunners']
# 0.20575521886348724
# b7a63fcd47bf44b5bc78260911e35c9d
# ScoreType.COSINE
# ------
# The Wildling! He is kissed by fire!
# ['NYYankees']
# 0.20163743197917938
# 339fde09037d4c268191eddb3bd03f82
# ScoreType.COSINE
# ------
# To much of a good thing is a bad thing
# ['entitledparents']
# 0.2011357992887497
# 8e9ada50659a42cb8a6004d4f6836552
# ScoreType.COSINE
# ------
# [NAME] “sociopath”.
# ['self']
# 0.20113275945186615
# 7d3d54e41ea94c41a52627025fe08d11
# ScoreType.COSINE
# ------
# Family first, this ain't no stranger trying to profit. This is blood.
# ['ChoosingBeggars']
# 0.1970125138759613
# 8c19cd43fa834e16b250e802befc899a
# ScoreType.COSINE
# ------
